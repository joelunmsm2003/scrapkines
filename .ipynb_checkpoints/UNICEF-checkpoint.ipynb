# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
plt.figure(figsize=(10,10))

# %%
df = pd.read_csv('../unicef.csv')

# %%
df.describe()
# Out:
#            1950.5      1951.5      1952.5      1953.5      1954.5      1955.5  \
# count   99.000000  129.000000  147.000000  168.000000  207.000000  231.000000
# mean   170.434343  166.966667  168.187075  165.081548  159.725121  161.594805
# std    133.367353  123.611996  116.904076  111.432534  106.475020  105.020431
# min     25.600000   24.800000   23.800000   22.700000   21.800000   21.200000
# 25%     38.650000   44.300000   48.550000   48.575000   59.600000   59.900000
# 50%    125.000000  134.500000  146.800000  143.650000  143.400000  151.300000
# 75%    298.900000  284.300000  276.450000  259.825000  244.900000  247.600000
# max    452.000000  430.900000  426.700000  423.200000  420.000000  416.500000
#
#            1956.5      1957.5      1958.5      1959.5     ...          2008.5  \
# count  261.000000  264.000000  267.000000  282.000000     ...      585.000000
# mean   166.280843  161.944697  156.336704  153.798936     ...       41.547350
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 71 columns):
# ISO Code               588 non-null object
# Country Name           588 non-null object
# Uncertainty bounds*    588 non-null object
# 1950.5                 99 non-null float64
# 1951.5                 129 non-null float64
# 1952.5                 147 non-null float64
# 1953.5                 168 non-null float64
# 1954.5                 207 non-null float64
# 1955.5                 231 non-null float64
# 1956.5                 261 non-null float64
# 1957.5                 264 non-null float64
# 1958.5                 267 non-null float64
# 1959.5                 282 non-null float64
# 1960.5                 303 non-null float64
# 1961.5                 303 non-null float64
# 1962.5                 309 non-null float64
# 1963.5                 327 non-null float64
# 1964.5                 345 non-null float64
# 1965.5                 357 non-null float64
# ...

# %%
df.groupby('2017.5').size().sort_values(ascending=False)
# Out:
# 2017.5
# 3.3     11
# 3.5      8
# 5.1      7
# 3.7      6
# 9.5      5
# 7.9      5
# 5.3      5
# 4.0      5
# 2.7      5
# 3.1      4
# 7.6      4
# 4.3      4
# 4.2      4
# 4.1      4
# 4.6      4
# 8.1      4
# 11.5     4
# 2.2      4
# 8.8      3
# 17.2     3
# 16.5     3
# 9.4      3
# 5.7      3
# 6.2      3
# 9.1      3
# 13.1     3
# 2.1      3
# 7.0      3
# 15.0     3
# 7.4      3
#         ..
# 53.4     1
# 53.9     1
# 54.0     1
# 56.1     1
# 56.2     1
# 56.3     1
# 56.7     1
# 57.0     1
# 57.7     1
# 49.3     1
# 49.2     1
# 49.0     1
# 45.6     1
# 42.2     1
# 42.3     1
# 42.5     1
# 43.1     1
# 43.3     1
# 44.3     1
# 45.4     1
# 45.7     1
# 48.6     1
# 47.3     1
# 47.5     1
# 47.6     1
# 47.9     1
# 48.0     1
# 48.1     1
# 48.3     1
# 1.0      1
# Length: 365, dtype: int64

# %%
sns.distplot(df[df['2017.5']<100]['2017.5'].fillna(0))

# %%
df1=df[['2017.5','2016.5']]

# %%
sns.relplot(y="2017.5", x="Country Name" , data=df[df['2017.5']<100])

# %%
sns.catplot(x="2014.5", y="Overall",  data=top_ten_countries_data,height=5.27, aspect=11.7/5.27);
plt.xticks(rotation=90)
