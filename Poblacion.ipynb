# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../adult.data.csv',names=['education','age','marital-status','workclass','occupation','race','sex','cod','capital-gain','capital-loss','native-country','hours-per-week'])

# %%
df.head()
# Out:
#                               education  age       marital-status  \
# 39  State-gov        77516    Bachelors   13        Never-married
# 50  Self-emp-not-inc 83311    Bachelors   13   Married-civ-spouse
# 38  Private          215646     HS-grad    9             Divorced
# 53  Private          234721        11th    7   Married-civ-spouse
# 28  Private          338409   Bachelors   13   Married-civ-spouse
#
#                                       workclass      occupation    race  \
# 39  State-gov        77516         Adm-clerical   Not-in-family   White
# 50  Self-emp-not-inc 83311      Exec-managerial         Husband   White
# 38  Private          215646   Handlers-cleaners   Not-in-family   White
# 53  Private          234721   Handlers-cleaners         Husband   Black
# 28  Private          338409      Prof-specialty            Wife   Black
#
#                                  sex   cod  capital-gain  capital-loss  \
# ...

# %%
plt.xticks(rotation=90) 

sns.set(rc={'figure.figsize':(15.7,8.27)})

sns.countplot(df['occupation'])

# %%
#sns.relplot(x="relationship", y="sex", data=df,height=5.27, aspect=15.7/12.27);

# %%
sns.kdeplot(df['age'])

# %%
df['age'].value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: age, dtype: int64

# %%
sns.catplot(x="occupation", y="cod",data=df[df['cod']<30000], hue="sex",height=5.07, aspect=15.7/5.27);

# %%
sns.jointplot(x="age", y="capital-loss", data=df,kind="kde");

# %%
df
# Out:
#                                  education  age          marital-status  \
# 39  State-gov        77516       Bachelors   13           Never-married
# 50  Self-emp-not-inc 83311       Bachelors   13      Married-civ-spouse
# 38  Private          215646        HS-grad    9                Divorced
# 53  Private          234721           11th    7      Married-civ-spouse
# 28  Private          338409      Bachelors   13      Married-civ-spouse
# 37  Private          284582        Masters   14      Married-civ-spouse
# 49  Private          160187            9th    5   Married-spouse-absent
# 52  Self-emp-not-inc 209642        HS-grad    9      Married-civ-spouse
# 31  Private          45781         Masters   14           Never-married
# 42  Private          159449      Bachelors   13      Married-civ-spouse
# 37  Private          280464   Some-college   10      Married-civ-spouse
# 30  State-gov        141297      Bachelors   13      Married-civ-spouse
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-17-ab93f6adf255> in <module>()
# ----> 1 result = df.pivot(columns='race', values='sex')
#       2 sns.heatmap(result, annot=True, fmt="g", cmap='viridis')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/reshape/reshape.pyc in pivot(self, index, columns, values)
#     398         else:
#     399             index = self[index]
# --> 400         index = MultiIndex.from_arrays([index, self[columns]])
#     401
#     402         if is_list_like(values) and not isinstance(values, tuple):
# ...
